# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
# Select the range of dates to use  etc
card_data = pd.read_csv('Cardano.csv',
    index_col =["SNo"],
    parse_dates=['Date'])
start = "2020-01-01"
end = "2021-07-31"
mask = (card_data['Date'] >= start) & (card_data['Date'] <= end)
card_data = card_data.loc[mask]
card_data.head()
# Out:
#           Date  Price  Open  High   Low       Vol.  Change %
# SNo
# 702 2020-01-01   0.02  0.02  0.02  0.01  4630000.0       0.0
# 703 2020-01-02   0.02  0.02  0.02  0.02  3790000.0       0.0
# 704 2020-01-03   0.02  0.02  0.02  0.02  1250000.0       0.0
# 705 2020-01-04   0.02  0.02  0.02  0.02   510050.0       0.0
# 706 2020-01-05   0.02  0.02  0.02  0.02   583250.0       0.0

# %%
card_data.describe
# Out:
# <bound method NDFrame.describe of            Date   Price    Open    High     Low       Vol.  Change %
# SNo
# 702  2020-01-01    0.02    0.02    0.02    0.01  4630000.0      0.00
# 703  2020-01-02    0.02    0.02    0.02    0.02  3790000.0      0.00
# 704  2020-01-03    0.02    0.02    0.02    0.02  1250000.0      0.00
# 705  2020-01-04    0.02    0.02    0.02    0.02   510050.0      0.00
# 706  2020-01-05    0.02    0.02    0.02    0.02   583250.0      0.00
# ...         ...     ...     ...     ...     ...        ...       ...
# 1247 2021-07-27  300.19  302.53  312.25  284.90   339840.0     -0.85
# 1248 2021-07-28  297.72  300.18  308.61  292.69   199090.0     -0.82
# 1249 2021-07-29  311.50  297.72  315.55  293.12   172600.0      4.63
# 1250 2021-07-30  320.47  311.99  323.68  300.37   187140.0      2.88
# 1251 2021-07-31  330.81  320.47  332.82  313.59   136270.0      3.23
#
# [549 rows x 7 columns]>

# %%
#Chart for daily price changes 2020-present
area = px.area(data_frame = card_data ,
               y = "Price",
               x="Date",
               title = 'Cardano(ADA) Daily Price')

area.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

area.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
area.update_layout(showlegend = True,
    title = {
        'text': 'Cardano(ADA) Daily Price (2020-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

area.show()
# Out:
# <div>                            <div id="38eb1a33-700a-4c3d-b763-7478977ca8eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38eb1a33-700a-4c3d-b763-7478977ca8eb")) {                    Plotly.newPlot(                        "38eb1a33-700a-4c3d-b763-7478977ca8eb",                        [{"hovertemplate":"Date=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","type":"scatter","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:
# ...

# %% [markdown]
# Covid spike shows a clear plateau right until summer 2021 when things start to return to normalcy

# %%
line = px.line(data_frame=card_data,
               x = "Date" ,
               y="Change %",
               title = 'Cardano(ADA) Daily Percentage Change(2019-Present)')

line.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

line.update_yaxes(title_text = 'Perctange Change', ticksuffix = '%')
line.update_layout(showlegend = True,
    title = {
        'text': 'Cardano(ADA) Daily Percentage Change(2019-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

line.show()
# Out:
# <div>                            <div id="222854c9-3f52-4f1b-bd2f-4299780ed353" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("222854c9-3f52-4f1b-bd2f-4299780ed353")) {                    Plotly.newPlot(                        "222854c9-3f52-4f1b-bd2f-4299780ed353",                        [{"hovertemplate":"Date=%{x}<br>Change %=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00
# ...

# %%
#Analyzing top 50 cryptocurrencies
data = pd.read_csv('ALL_COMBINED.csv',parse_dates=['Date'])
mask2 = (data['Date'] >= start) & (data['Date'] <= end)
data = data.loc[mask2]
data.head
# Out:
# <bound method NDFrame.head of       Currency_Name       Date    Price     Open     High      Low  \
# 701            Aave 2020-01-01  0.02000  0.02000  0.02000  0.01000
# 702            Aave 2020-01-02  0.02000  0.02000  0.02000  0.02000
# 703            Aave 2020-01-03  0.02000  0.02000  0.02000  0.02000
# 704            Aave 2020-01-04  0.02000  0.02000  0.02000  0.02000
# 705            Aave 2020-01-05  0.02000  0.02000  0.02000  0.02000
# ...             ...        ...      ...      ...      ...      ...
# 51967           XPR 2020-01-05  0.19455  0.19313  0.19708  0.19289
# 51968           XPR 2020-01-04  0.19311  0.19321  0.19366  0.19135
# 51969           XPR 2020-01-03  0.19321  0.18749  0.19380  0.18464
# 51970           XPR 2020-01-02  0.18748  0.19306  0.19310  0.18634
# 51971           XPR 2020-01-01  0.19307  0.19293  0.19508  0.19223
#
#               Vol.  Change %
# 701      4630000.0      0.00
# 702      3790000.0      0.00
# 703      1250000.0      0.00
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Currency_Name       Date    Price     Open     High      Low  \
# 701            Aave 2020-01-01  0.02000  0.02000  0.02000  0.01000
# 702            Aave 2020-01-02  0.02000  0.02000  0.02000  0.02000
# 703            Aave 2020-01-03  0.02000  0.02000  0.02000  0.02000
# 704            Aave 2020-01-04  0.02000  0.02000  0.02000  0.02000
# 705            Aave 2020-01-05  0.02000  0.02000  0.02000  0.02000
# ...             ...        ...      ...      ...      ...      ...
# 51967           XPR 2020-01-05  0.19455  0.19313  0.19708  0.19289
# 51968           XPR 2020-01-04  0.19311  0.19321  0.19366  0.19135
# 51969           XPR 2020-01-03  0.19321  0.18749  0.19380  0.18464
# 51970           XPR 2020-01-02  0.18748  0.19306  0.19310  0.18634
# 51971           XPR 2020-01-01  0.19307  0.19293  0.19508  0.19223
#
#               Vol.  Change %
# 701      4630000.0      0.00
# 702      3790000.0      0.00
# 703      1250000.0      0.00
# ...

# %%
area = px.area(data_frame= data ,
               x = "Date" ,
               y= "Price",
               line_group="Currency_Name" ,
               color = "Currency_Name" ,
               color_discrete_sequence=px.colors.qualitative.Alphabet_r,
               title = 'Area Plot for TOP 50 Cryptocurrencies (2021-Present)')

area.update_xaxes(
    title_text = 'Date',
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
            dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
            dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
            dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
            dict(step = 'all')])))

area.update_yaxes(title_text = 'Price in USD', ticksuffix = '$')
area.update_layout(showlegend = True,
    title = {
        'text': 'Area Plot for TOP 50 Cryptocurrencies (Jan 2021-Present)',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

area.show()
# Out:
# <div>                            <div id="30a6b548-29e8-4596-9164-58c0d5c7085f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30a6b548-29e8-4596-9164-58c0d5c7085f")) {                    Plotly.newPlot(                        "30a6b548-29e8-4596-9164-58c0d5c7085f",                        [{"hovertemplate":"Currency_Name=Aave<br>Date=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"Aave","line":{"color":"#FA0087"},"marker":{"symbol":"circle"},"mode":"lines","name":"Aave","orientation":"v","showlegend":true,"stackgroup":"1","type":"scatter","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01
# ...

# %% [markdown]
# good old april 26th 2021 crypto spike, not much else meaningful. When the market is based on FOMO and feels analyzing it
# feels worthless without analyzing the underlying media causes.
