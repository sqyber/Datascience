# %%
import matplotlib as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping

# %%
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %%
spotify = pd.read_csv('spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape),
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0, # suppress output since we'll plot the curves
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1951

# %%
# Start the plot at epoch 10
history_df.loc[10:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1951

# %%
# add 3 hidden layers with 128 units each
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.2594 - val_loss: 0.2080
# Epoch 2/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.2044 - val_loss: 0.2021
# Epoch 3/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1979 - val_loss: 0.1989
# Epoch 4/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1947 - val_loss: 0.1992
# Epoch 5/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1921 - val_loss: 0.1999
# Epoch 6/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1908 - val_loss: 0.1970
# Epoch 7/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1893 - val_loss: 0.1980
# Epoch 8/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1875 - val_loss: 0.1962
# Epoch 9/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1862 - val_loss: 0.1959
# Epoch 10/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1855 - val_loss: 0.1963
# Epoch 11/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1847 - val_loss: 0.1966
# Epoch 12/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1838 - val_loss: 0.1996
# Epoch 13/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1834 - val_loss: 0.1968
# Epoch 14/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1844 - val_loss: 0.1971
# Epoch 15/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1817 - val_loss: 0.1972
# Epoch 16/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.1809 - val_loss: 0.1973
# Epoch 17/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.1807 - val_loss: 0.1978
# Epoch 18/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1803 - val_loss: 0.1965
# Epoch 19/50
# 48/48 [==============================] - 0s 8ms/step - loss: 0.1795 - val_loss: 0.1965
# Epoch 20/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1794 - val_loss: 0.1977
# Epoch 21/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1784 - val_loss: 0.1977
# Epoch 22/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1783 - val_loss: 0.1986
# Epoch 23/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1771 - val_loss: 0.1972
# Epoch 24/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1771 - val_loss: 0.1989
# Epoch 25/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1767 - val_loss: 0.1981
# Epoch 26/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1766 - val_loss: 0.2003
# Epoch 27/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1759 - val_loss: 0.1979
# Epoch 28/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1755 - val_loss: 0.1984
# Epoch 29/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1749 - val_loss: 0.1989
# Epoch 30/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1770 - val_loss: 0.1987
# Epoch 31/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1743 - val_loss: 0.1990
# Epoch 32/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1736 - val_loss: 0.1983
# Epoch 33/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1748 - val_loss: 0.1992
# Epoch 34/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1728 - val_loss: 0.2005
# Epoch 35/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1734 - val_loss: 0.2004
# Epoch 36/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1723 - val_loss: 0.1981
# Epoch 37/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1723 - val_loss: 0.2012
# Epoch 38/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1715 - val_loss: 0.2005
# Epoch 39/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1997
# Epoch 40/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1704 - val_loss: 0.2011
# Epoch 41/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1701 - val_loss: 0.2020
# Epoch 42/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1698 - val_loss: 0.2026
# Epoch 43/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.2021
# Epoch 44/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1691 - val_loss: 0.2016
# Epoch 45/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1682 - val_loss: 0.2026
# Epoch 46/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1687 - val_loss: 0.2016
# Epoch 47/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1681 - val_loss: 0.2026
# Epoch 48/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1689 - val_loss: 0.2020
# Epoch 49/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1678 - val_loss: 0.2028
# Epoch 50/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1672 - val_loss: 0.2027
# Minimum Validation Loss: 0.1959

# %%
early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    callbacks=[early_stopping]
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 48/48 [==============================] - 1s 13ms/step - loss: 0.2498 - val_loss: 0.2069
# Epoch 2/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2017 - val_loss: 0.1986
# Epoch 3/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1961 - val_loss: 0.1977
# Epoch 4/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1934 - val_loss: 0.1990
# Epoch 5/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1909 - val_loss: 0.1957
# Epoch 6/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1891 - val_loss: 0.1967
# Epoch 7/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1887 - val_loss: 0.2001
# Epoch 8/50
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1869 - val_loss: 0.1972
# Epoch 9/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1865 - val_loss: 0.1955
# Epoch 10/50
# 48/48 [==============================] - 0s 2ms/step - loss: 0.1845 - val_loss: 0.1962
# Minimum Validation Loss: 0.1955
